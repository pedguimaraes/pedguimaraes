# %% [markdown]
# <a href="https://colab.research.google.com/github/pedguimaraes/pedguimaraes/blob/main/Aula2_estruturadedecisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Estruturas de Decisão em Python**
#
# **Objetivo:**
#
# * Introduzir o conceito de estruturas de decisão.
# * Ensinar como tomar decisões dentro de um programa utilizando as estruturas de decisão em Python. Vamos começar com os conceitos mais simples e avançar para casos mais elaborados, incluindo uso de if, if else, elif e if aninhados.
# * Praticar a criação de programas simples que utilizam if-else e if-else aninhados.
#
# # **1. O que são Estruturas de Decisão?**
#
# As estruturas de decisão permitem que o programa tome diferentes ações com base em condições específicas. Em Python, temos:
#
# * if: Executa um bloco de código apenas se a condição for verdadeira.
# * if else: Executa um bloco de código se a condição for verdadeira, e outro bloco se a condição for falsa.
# elif: Permite testar várias condições de maneira encadeada.
# * if aninhado: Um if dentro de outro, para verificar condições mais complexas.
# * Essas estruturas ajudam o programa a seguir diferentes caminhos dependendo dos dados de entrada.

# %% [markdown]
# #  **2. Como Representar Operadores Relacionais**
#
# ![op.png](data:image/png;base64,...)

# %% [markdown]
# # **Operadores Relacionais em Python**
#
# **== (Igual a)**
#
# Verifica se dois valores são iguais.
# Exemplo:
#
# ```
# x = 5
# y = 5
# print(x == y)  # True
# ```

# %% [markdown]
# **!= (Diferente de)**
#
# Verifica se dois valores são diferentes.
# Exemplo:
#
# ```
# x = 5
# y = 3
# print(x != y)  # True
# ```

# %% [markdown]
# **> (Maior que)**
#
# Verifica se o valor da esquerda é maior que o da direita.
# Exemplo:
#
#
# ```
# x = 7
# y = 3
# print(x > y)  # True
# ```

# %% [markdown]
# **< (Menor que)**
#
# Verifica se o valor da esquerda é menor que o da direita.
# Exemplo:
#
# ```
# x = 2
# y = 5
# print(x < y)  # True
# ```

# %% [markdown]
# **>= (Maior ou igual a)**
#
# Verifica se o valor da esquerda é maior ou igual ao da direita.
# Exemplo:
#
#
# ```
# x = 5
# y = 5
# print(x >= y)  # True
# ```

# %% [markdown]
# **<= (Menor ou igual a)**
#
# Verifica se o valor da esquerda é menor ou igual ao da direita.
# Exemplo:
#
#
# ```
# x = 3
# y = 7
# print(x <= y)  # True
# ```

# %% [markdown]
# # **Resumindo:**
# ***
# ```
# ==  : Verifica se dois valores são iguais.
# !=  : Verifica se dois valores são diferentes.
# >   : Verifica se o valor à esquerda é maior.
# <   : Verifica se o valor à esquerda é menor.
# >=  : Verifica se o valor à esquerda é maior ou igual.
# <=  : Verifica se o valor à esquerda é menor ou igual.
#
# ```
# ***
#
# * Esses operadores são usados para comparações e são fundamentais em estruturas de decisão (if, while, etc.) no Python.

# %% [markdown]
# # **3. Operadores Lógicos**
# Operadores lógicos são símbolos ou palavras-chave, como **AND, OR e NOT**, usados para combinar expressões booleanas (verdadeiro ou falso), formando condições mais complexas que são avaliadas para um único resultado verdadeiro ou falso.
#
# Eles são fundamentais em programação e lógica de computação para tomar decisões, filtrar dados e construir algoritmos, permitindo a criação de lógicas mais sofisticadas através da junção de múltiplos testes.

# %% [markdown]
# * and → Verdadeiro se todas as condições forem verdadeiras.
# * or → Verdadeiro se pelo menos uma condição for verdadeira.
# * not → Inverte o valor lógico (Verdadeiro ↔ Falso).

# %% [markdown]
# # **4. Estrutura if**
#
# O comando if é a estrutura mais simples de decisão. Ele executa um bloco de código somente se a condição fornecida for verdadeira.
#
# Sintaxe:
#
# `if condição:`
#     # código a ser executado se a condição for verdadeira

# %% [markdown]
# **Exemplo 1:**
#
# Vamos verificar se o valor de x é maior que 5

# %%
x = 10
if x > 5:
  print("x é maior que 5")
# Out:
# x é maior que 5

# %% [markdown]
# **Exemplo 2:**
#
# Vamos verificar se o número fornecido é positivo.

# %%
numero = int(input("Digite um número: "))

if numero > 0:
    print("O número é positivo.")
# Out:
# Digite um número: 5
# O número é positivo.

# %% [markdown]
# **Explicação:** O código verifica se o número fornecido é maior que zero. Se for, ele imprime "O número é positivo."

# %% [markdown]
# # **4.1 Estrutura if else**
#
# O *if else* é uma extensão do if. Ele permite que você execute uma ação se a condição for verdadeira e outra ação se a condição for falsa.
#
# Sintaxe:
#
# ```
# if condição:
#     # código a ser executado se a condição for verdadeira
# else:
#     # código a ser executado se a condição for falsa
# ```

# %% [markdown]
# **Exemplo 1:**
#
# VAmos verificar se o valor de x é maior ou menor ou igual a 5

# %%
x = 3
if x > 5:
    print("x é maior que 5")
else:
    print("x é menor ou igual a 5")
# Out:
# x é menor ou igual a 5

# %% [markdown]
# **Exemplo 2:**
#
# Agora, vamos verificar se o número fornecido é positivo ou negativo.

# %%
numero = int(input("Digite um número: "))

if numero > 0:
    print("O número é positivo.")
else:
    print("O número é negativo ou zero.")

# %% [markdown]
# **Explicação**:
#
# Se o número for maior que zero, o programa imprime "O número é positivo". Caso contrário, imprime "O número é negativo ou zero".

# %% [markdown]
# # **4.2 Estrutura elif (else if)**
#
# O comando elif (abreviação de "else if") é útil quando temos várias condições a serem verificadas, uma após a outra. Ele permite verificar várias possibilidades sem precisar de múltiplos if encadeados.
#
# ```
# if condição1:
#     # código para a primeira condição
# elif condição2:
#     # código para a segunda condição
# else:
#     # código para quando nenhuma das condições for verdadeira
# ```

# %% [markdown]
# **Exemplo 1:**

# %%
x = 7
if x > 10:
    print("x é maior que 10")
elif x > 5:
    print("x é maior que 5, mas menor ou igual a 10")
else:
    print("x é menor ou igual a 5")
# Out:
# x é maior que 5, mas menor ou igual a 10

# %% [markdown]
# **Agora, vamos fazer um programa que classifica a nota de um aluno.**

# %%
nota = float(input("Digite a nota do aluno: "))

if nota >= 7:
    print("Aluno aprovado!")
elif nota >= 5:
    print("Aluno em recuperação.")
else:
    print("Aluno reprovado.")

# %% [markdown]
# **Explicação:**
#
# * Se a nota for maior ou igual a 7, o aluno é "aprovado".
# * Se a nota for entre 5 e 7, o aluno está "em recuperação".
# * Caso contrário, o aluno foi "reprovado"

# %% [markdown]
# # **4.3 Estruturas de Decisão Aninhadas**
#
# Um if aninhado é quando temos um if dentro de outro if. Isso é útil para verificar condições mais complexas, onde a verificação de uma condição depende do resultado de outra.
#
# **Sintaxe:**
#
#
# ```
# if condição1:
#     if condição2:
#         # código para quando ambas as condições forem verdadeiras
#     else:
#         # código para quando a condição1 for verdadeira e a condição2 for falsa
# else:
#     # código para quando a condição1 for falsa
# ```

# %%
nota = float(input("Digite a nota do aluno: "))
presenca = int(input("Digite a presença do aluno (em %): "))

if nota >= 7:
    if presenca >= 75:
        print("Aluno aprovado com boa nota e presença!")
    else:
        print("Aluno aprovado, mas com presença abaixo do necessário.")
else:
    if presenca >= 75:
        print("Aluno reprovado pela nota, mas com presença boa.")
    else:
        print("Aluno reprovado por nota e presença.")
# Out:
# Aprovado

# %% [markdown]
# **Explicação:**
#
# * Se o aluno tiver uma nota maior ou igual a 7:
# * Se a presença for maior ou igual a 75%, o aluno é aprovado com boa nota e presença.
# * Caso contrário, o aluno é aprovado, mas com presença abaixo do necessário.
# * Se a nota for abaixo de 7:
# * Se a presença for maior ou igual a 75%, o aluno é reprovado por nota, mas com boa presença.
# *Caso contrário, o aluno é reprovado tanto por nota quanto por presença.

# %% [markdown]
# # **5. Exemplos Mais Elaborados**
#
#
# Vamos criar um sistema de votação, onde um usuário pode votar se tiver idade apropriada, e a votação pode ser para diferentes tipos de cargos (presidente, governador, etc.).

# %%
idade = int(input("Digite sua idade: "))

if idade >= 16:
    cargo = input("Para qual cargo você deseja votar? (presidente, governador, prefeito): ").lower()
    if cargo == "presidente":
        print("Você pode votar para presidente.")
    elif cargo == "governador":
        print("Você pode votar para governador.")
    elif cargo == "prefeito":
        print("Você pode votar para prefeito.")
    else:
        print("Cargo inválido.")
else:
    print("Você não tem idade suficiente para votar.")

# %% [markdown]
# **Explicação:**
#
# * Se o usuário tem 16 anos ou mais, ele pode escolher para qual cargo deseja votar.
# * O programa verifica o cargo escolhido (presidente, governador, prefeito) e responde adequadamente.
# * Caso a idade seja menor que 16, o programa avisa que o usuário não pode votar.

# %% [markdown]
# **Exemplo 2: Calculadora de Impostos**
#
# Agora, vamos criar uma calculadora de impostos com base na faixa de renda do usuário.

# %%
renda = float(input("Digite sua renda mensal: "))

if renda <= 2000:
    print("Você não paga imposto.")
elif renda <= 5000:
    imposto = renda * 0.10
    print(f"Você paga 10% de imposto, o valor é: R${imposto:.2f}")
elif renda <= 10000:
    imposto = renda * 0.15
    print(f"Você paga 15% de imposto, o valor é: R${imposto:.2f}")
else:
    imposto = renda * 0.20
    print(f"Você paga 20% de imposto, o valor é: R${imposto:.2f}")

# %% [markdown]
# **Explicação:**
#
# * O programa verifica a faixa de renda do usuário e calcula o imposto correspondente:
# * Até 2000: não paga imposto.
# * De 2000 até 5000: paga 10%.
# * De 5000 até 10000: paga 15%.
# * Acima de 10000: paga 20%.

# %% [markdown]
# # **Lista de Exercicio**
#
# 1. Receba dois números do usuário e mostre qual deles é o maior.
#
# 2. Solicite a idade do usuário e informe se ele é menor de idade, maior de idade ou idoso (considerando 18 e 65 anos como limites).
#
# 3. Peça ao usuário para inserir a idade de uma pessoa e classifique-a como "Criança" (0-12 anos), "Adolescente" (13-17 anos), "Adulto" (18-64 anos) ou "Idoso" (65+ anos).
#
#
# 5. Crie uma calculadora simples que permita ao usuário escolher uma operação (adição, subtração, multiplicação ou divisão) e dois números, e então exiba o resultado.
#
# 6. Peça um número ao usuário e informe se ele é par ou ímpar.
#
# 7. Crie um programa que simule um sistema de login. Solicite um nome de usuário e senha e verifique se as credenciais estão corretas.
#
# 8. Receba a nota de um aluno e classifique-a como A (90-100), B (80-89), C (70-79), D (60-69), ou F (menos de 60).
#
# 9. Peça ao usuário seu peso e altura, calcule o Índice de Massa Corporal (IMC) e classifique-o como "Abaixo do peso", "Peso normal", "Sobrepeso" ou "Obesidade".
#
# 10. Solicite o preço de um produto e aplique um desconto de 10% se o preço for maior que R$ 100. Exiba o valor final.
#
# 11. Desenvolva um programa que permita ao usuário escolher uma operação (saque, depósito) e simule o comportamento de um caixa eletrônico com validações básicas (ex.: saldo insuficiente para saque).
#
# 12. Faça um programa que leia a idade e a categoria de um jogador de futebol (juvenil, adulto, veterano) e calcule a sua classificação no time.

# %%
# ex 1 resposta
num1 = (input("digite o primeiro numero: "))
num2 = (input("digite o segundo numero: "))

if( num1 > num2 ):
    print(f" o maior é: {num1}")

else: print(f"o maior é: {num2}")

# %%
# ex 2 resposta
idade = int (input("digite sua idade: "))

if idade < 18:
    print(f"menor de idade.",{idade})

elif idade <= 64:
    print(f"adulto.", {idade})

else:
    print(f"idoso.",{idade} )

# %%
# ex 3 resposta

idade = int (input("digite sua idade: "))

if idade < 12:
    print(f"criança.", {idade})

elif idade > 17:
    print(f"adolescente.", {idade})

elif idade < 18:
    print(f"menor de idade.",{idade})

elif idade <= 64:
    print(f"adulto.", {idade})

else:
    print(f"idoso.",{idade} )

# %%
# ex 4 resposta

num1 = float(input("digite o primeiro numero: "))
num2 = float(input("digite o segundo numero: "))

resposta = (input("o que quer fazer?" ))
somar = num1 + num2
subtrair = num1 - num2
multiplicar = num1 * n
um2
dividir = num1 / num2

# %% [markdown]
# # Exercicios de fixação
#
# **Exercícios Simples com if / if-else**
#
# 1. Receba dois números e mostre qual é o maior.
# 2. Solicite a idade do usuário e informe se é maior de idade.
# 3. Verifique se um número é positivo, negativo ou zero.
# 4. Peça um número e informe se é par ou ímpar.
# 5. Pergunte a altura e informe se a pessoa pode entrar no brinquedo (mínimo 1,50m).
#
# **Exercícios com elif**
#
# 6. Classifique a nota de um aluno (A, B, C, D, F).
# 7. Solicite a idade e classifique: criança, adolescente, adulto ou idoso.
# 8. Pergunte o mês (1-12) e mostre a estação correspondente.
# 9. Receba o peso e altura e calcule o IMC, mostrando a classificação.
# 10. Solicite um número de 1 a 7 e mostre o dia da semana.
#
# **Exercícios com if aninhado**
#
# 11. Sistema de login com usuário e senha.
# 12. Aprovação de aluno considerando nota e presença.
# 13. Desconto extra em compras altas se pagamento à vista.
# 14. Empréstimo na biblioteca: precisa estar cadastrado e sem atraso.
# 15. Avaliação física: idade ≥ 18 e desempenho ≥ 70%.
# 16. Saque bancário: conta ativa e saldo suficiente.
# 17. Promoção e-commerce: cliente cadastrado e compra acima de R$500.
# 18. Votação: idade ≥16 e título válido.
# 19. Concurso: idade ≥18 e escolaridade adequada.
# 20. Transporte escolar: distância >2 km e frequência ≥80%.
#
# **Exercícios com operadores lógicos (and, or, not)**
#
# 21. Entrada em festa: idade ≥18 ou acompanhado dos pais.
# 22. Meia-entrada no cinema: estudante ou menor de 18 anos.
# 23. Biblioteca: acesso permitido a alunos ou funcionários.
# 24. Login alternativo: senha correta ou computador autorizado.
# 25. Promoção: desconto se compra > R$100 ou cliente VIP.
# 26. Parque: entrada proibida se idade <12 **ou** >60.
# 27. Doação de sangue: idade entre 18 e 65 e peso >50kg.
# 28. Alarme: dispara se ninguém em casa ou porta aberta.
# 29. Guarda-chuva: sair se não estiver chovendo.
# 30. Jogo de adivinhação: vence se número igual ao secreto ou ±1.
