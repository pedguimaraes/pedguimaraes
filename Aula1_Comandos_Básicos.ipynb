# %% [markdown]
# <a href="https://colab.research.google.com/github/pedguimaraes/pedguimaraes/blob/main/Aula1_Comandos_B%C3%A1sicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Algoritmos - Comandos Básicos de Entrada, Saída e Operadores Aritméticos**

# %% [markdown]
# **🎯 Objetivo da Aula**
#
# Nesta aula, vamos aprender:
#
# ✅ Como funciona a entrada e saída de dados em Python.
#
# ✅ Como utilizar o input() para receber dados do usuário.
#
# ✅ Como exibir informações na tela com print().
#
# ✅ O que são operadores aritméticos e como utilizá-los.

# %% [markdown]
# # 1️⃣ Entrada e Saída de Dados
#
# **🔹 Saída de Dados: print()**
#
# A função print() é utilizada para exibir informações na tela.
#
# 📌 Exemplo Simples:

# %%
print("Olá, mundo!")
print("Seja bem-vindo ao curso de Algoritmos!")
# Out:
# Olá, mundo!
# Seja bem-vindo ao curso de Algoritmos!

# %% [markdown]
# **🔹 Exibindo Variáveis no print()**

# %%
nome = "João"
idade = 25
print("Nome:", nome)
print("Idade:", idade)
# Out:
# Nome: João
# Idade: 25

# %% [markdown]
# **🔹 Exibindo com f-strings (Interpolação de Variáveis)**

# %%
nome = "Maria"
idade = 22
print(f"Olá, {nome}! Você tem {idade} anos.")
# Out:
# Olá, Maria! Você tem 22 anos.

# %% [markdown]
# **🔹 Entrada de Dados: input()**
#
# A função input() permite que o usuário digite um valor no programa.
#
# 💡 Todos os valores recebidos pelo input() são do tipo string.
#
# 📌 Exemplo Simples

# %%
nome = input("Digite seu nome: ")
print(f"Bem-vindo, {nome}!")

# %% [markdown]
# **🔹 Convertendo Tipos de Dados (int e float)**
#
# Se quisermos receber um número, precisamos converter o valor digitado:

# %%
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
print(f"Você tem {idade} anos e {altura} metros de altura.")
# Out:
# Digite sua idade: 4
# Digite sua altura: 2.45
# Você tem 4 anos e 2.45 metros de altura.

# %% [markdown]
# # **2️⃣ Operadores Aritméticos**
#
# ![operadores aritmeticos.png](data:image/png;base64,...)
# Os operadores aritméticos realizam operações matemáticas básicas.

# %% [markdown]
# # **📌 Exemplos Práticos**
#
# **🔹 Calculadora Simples**

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

soma = num1 + num2
subtracao = num1 - num2
multiplicacao = num1 * num2
divisao = num1 / num2

print(f"Soma: {soma}")
print(f"Subtração: {subtracao}")
print(f"Multiplicação: {multiplicacao}")
print(f"Divisão: {divisao}")

# %% [markdown]
# # **3️⃣ Conclusão**
#
# ✅ print() exibe informações na tela.
#
# ✅ input() recebe dados do usuário.
#
# ✅ Devemos converter os dados (int(), float()) quando necessário.
#
# ✅ Operadores aritméticos realizam cálculos matemáticos.
#
# **🚀 Agora é sua vez! Pratique os exercícios e crie seus próprios exemplos! 😃**

# %% [markdown]
# # Exercicios Práticos
#
#
# **1. Salario**
#
# Crie um programa que leia o nome e o salário de um funcionário, mostrando no
# final uma mensagem.
#
# **2. Media**
#
# Faça um programa que leia as duas notas de um aluno em uma matéria e mostre
# na tela a sua média na disciplina.
#
# **3. Operadores**
#
# Crie um algoritmo que leia um número real e mostre na tela o seu dobro e a
# sua terça parte.
#
# **4. Cálculo de área de um quadrado**
#
# A = b.h
#
# **5. Peça o lado de um quadrado e mostre sua área.**
#
# Área = lado²
#
# **6. Cálculo de área de um triângulo**
#
# Área = (base × altura) / 2
#
# **7. Cálculo de área de um círculo:**
#
#  Área = π × raio²
#
# **8. Construção**
#
# Faça um algoritmo que leia a largura e altura de uma parede, calcule e
# mostre a área a ser pintada e a quantidade de tinta necessária para o serviço,
# sabendo que cada litro de tinta pinta uma área de 2metros quadrados.
#
#
# **9. IMC (Índice de Massa Corporal)**
#
#  IMC = peso / (altura ** 2)
#
#
# **10. Múltiplos**
#
#  Elaborar um algoritmo que lê 2 valores a e b e os escreve com a mensagem: "São múltiplos" ou "Não são múltiplos".
#
# **11. Desconto em compras**
#
#  Peça o valor de um produto e aplique um desconto de 10%.
#
# **12. Aumento salarial**
#
# Peça o salário de um funcionário e aumente em 15%.
#
# **13. Cálculo do tempo de viagem**
#
# Peça a distância a ser percorrida e a velocidade média, depois calcule o tempo da viagem
#
# *Tempo = distância / velocidade*
#
# **14. Conta de luz**
#
# Peça a quantidade de kWh consumidos e o valor por kWh, depois calcule o valor da conta de energia.
#
# **15. Conversão de dinheiro**
#
# Peça um valor em reais e converta para dólares. (Considere o valor do dólar como R$ 5,00)
#
# **16. Salário**
#
# Crie um programa que leia o número de dias trabalhados em um mês e mostre o
# salário de um funcionário, sabendo que ele trabalha 8 horas por dia e ganha R\$25,00 por hora trabalhada.
#
# **17. Locadora**
#
# A locadora de carros precisa da sua ajuda para cobrar seus serviços. Escreva
# um programa que pergunte a quantidade de Km percorridos por um carro alugado e a
# quantidade de dias pelos quais ele foi alugado. Calcule o preço total a pagar,
# sabendo que o carro custa R\$ 90,00 por dia e R$ 0,20 por Km rodado.
#
# **18. Custo de imposto**
#
#  O custo ao consumidor de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos (aplicados ao custo de fábrica). Supondo que a percentagem do distribuidor seja de 28% e os impostos de 45%, escrever um algoritmo que leia o custo de fábrica de um carro e escreva o custo ao consumidor.

# %%
# ex 1 resposta

print(input("digite seu nome: "))
print(input("digite seu salario:"))

print("obrigado por informar.")
# Out:
# digite seu nome: Pedro
# Pedro
# digite seu salario:2300
# 2300
# obrigado por informar.

# %%
# ex 2 resposta

n1 = float(input("digite a nota 1: "))
n2 = float(input("digite a nota 2:"))

media = (n1+n2)/2

print(f"media: {media}")

# %%
# ex 3 resposta

num = float(input("digite o numero"))

dobro = num * 2
parte = num / 3

print("seu dobro eh{}".format(dobro))
print("sua terca parte eh{}".format(parte))

# %%
# ex 4 resposta

lado = int(input("digite um lado: "))
area = (lado*lado)

print(f"a area do quadrado de lado {lado} eh {area}")

# %%
# ex 5 resposta

lado = int(input9("digite o valor do lado: "))

area = (lado*lado)

print("a area eh {}".format(area))

# %%
# ex 6 resposta

base = int(input("digite o valor da base: "))
altura = int(input("digite o valor da altura: "))

area = ((base*altura)/2)

print("a area do triangulo eh {}".format(area))
# Out:
# digite o valor da base: 10
# digite o valor da altura: 5
# a area do triangulo eh 25.0

# %%
# ex 7 resposta

pi = 3.14
raio = float(input("digite o valor do raio do circulo: "))

area = (pi*(raio*raio))

print("a area do circulo eh {}".format(area))

# %%
# ex 8 resposta

largura = float(input("digite a largura da parede: "))
altura = float(input("digite a altura da parede: "))

area = (largura*altura)
litros = (area/2)

print("a area pintada eh de {}".format(area), "e a qtd de litros a ser utilizada eh de {}L".format(litros))
# Out:
# digite a largura da parede: 3
# digite a altura da parede: 2
# a area pintada eh de 6.0 e a qtd de litros a ser utilizada eh de 3.0L

# %%
peso = float(input("digite seu peso: "))
altura = float(input("digite sua altura: ").replace(',', '.'))

imc = (peso/(altura*altura))

print("seu imc eh{}".format(imc))

# %%
# ex 10 resposta

num1 = float(input("digite o primeiro numero: "))
num2 = float(input("digite o segundo numero: "))

if num1%num2 == 0:
    print("sao multiplos")
else:
      print("nao sao multiplos")
# Out:
# digite o primeiro numero: 3.5
# digite o segundo numero: 3.5
# sao multiplos

# %%
# ex 11 resposta

valor = float(input("digite o valor do produto: "))

desconto = (valor*0.1)

valor_final = (valor - desconto)

print("o valor final total eh {}".format(valor_final))
# Out:
# digite o valor do produto: 50
# o valor final total eh 45.0

# %%
# ex 12 resposta

salario = float(input("digite o valor do salario: "))

aumento = salario + (salario*0.15)

salario_final = (salario + aumento)

print("o salario aumentado eh {}".format(aumento))
# Out:
# digite o valor do salario: 2000
# o salario aumentado eh 2300.0

# %%
# ex 13 resposta

distancia = float(input("digite a distancia percorrida: "))
velocidade_media = float(input("digite a velocidade media: "))

tempo = (distancia/velocidade_media)

print("o tempo da viagem eh {}".format(tempo))

# %%
 # ex 14 resposta

 kWh = float(input("digite a quantidade de kWh consumida: "))
 valor_kWh = float(input("digite o valor por kWh: "))

 conta = (kWh*valor_kWh)

 print("o valor da conta eh {}".format(conta))

# %%
# ex 15 resposta

real = float(input("digite o valor em reais: "))
dolar = int(input("qual o valor atual do dolar?: "))

conversao = (real/dolar)

print("o valor em dolares sera de {}".format(conversao))
# Out:
# digite o valor em reais: 500
# qual o valor atual do dolar?: 5
# o valor em dolares sera de 100.0

# %%
# ex 16 resposta

qtd_dias = int(input("digite a quantidade de dias trabalhados: "))

salario = (qtd_dias*8*25)

print("o salario eh de {} reais".format(salario))
# Out:
# digite a quantidade de dias trabalhados: 25
# o salario eh de 5000 reais

# %%
# ex 17 resposta

km_total = int(input("digite a quantidade de km percorridos: "))

dias_alugados = int(input("digite a quantidade de dias alugados: "))

valor_km = (km_total*0.2)
valor_dias = (dias_alugados*90)
valor_total = (valor_km + valor_dias)

print("o total a pagar sera de {} reais.".format(valor_total))
# Out:
# digite a quantidade de km percorridos: 300
# digite a quantidade de dias alugados: 3
# o total a pagar sera de 330.0 reais.

# %%
# ex 18 resposta

valor_custo = float(input("digite o valor de custo:" ))
imposto = (valor_custo*0.45)
distribuidor = (valor_custo*0.28)
valor_compra = (valor_custo + imposto + distribuidor)

print("o valor da compra eh {}".format(valor_compra))
# Out:
# digite o valor de custo:37990
# o valor da compra eh 65722.7
